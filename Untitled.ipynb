# %%
import pandas as pd

# %%
dataset=pd.read_csv("z.csv")

# %%
dataset.head()
# Out:
#    sr no.                    Distric                         state  latitude  \
# 0        1            South Andamans   Andaman And Nicobar Islands       NaN
# 1        2                 Nicobars    Andaman And Nicobar Islands       NaN
# 2        3  North and Middle Andaman   Andaman And Nicobar Islands       NaN
# 3        4                   Kurnool                ANDHRA PRADESH       NaN
# 4        5                    Guntur                ANDHRA PRADESH       NaN
#
#    longitude  red zone  orange zone  green zone  Unnamed: 8  Unnamed: 9  \
# 0        NaN         1            0           0         NaN         NaN
# 1        NaN         0            0           1         NaN         NaN
# 2        NaN         0            0           1         NaN         NaN
# 3        NaN         1            0           0         NaN         NaN
# 4        NaN         1            0           0         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11 Unnamed: 12
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sr no.       733 non-null    int64
#  1   Distric      733 non-null    object
#  2   state        733 non-null    object
#  3   latitude     0 non-null      float64
#  4   longitude    0 non-null      float64
#  5   red zone     733 non-null    int64
#  6   orange zone  733 non-null    int64
#  7   green zone   733 non-null    int64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  2 non-null      object
# dtypes: float64(6), int64(4), object(3)
# memory usage: 74.6+ KB

# %%
data = dataset[['red zone','orange zone','green zone']]

# %%
data
# Out:
#      red zone  orange zone  green zone
# 0           1            0           0
# 1           0            0           1
# 2           0            0           1
# 3           1            0           0
# 4           1            0           0
# ..        ...          ...         ...
# 728         0            0           1
# 729         0            0           1
# 730         0            0           1
# 731         0            0           1
# 732         0            0           1
#
# [733 rows x 3 columns]

# %%
zones=data

# %%
zones
# Out:
#      red zone  orange zone  green zone
# 0           1            0           0
# 1           0            0           1
# 2           0            0           1
# 3           1            0           0
# 4           1            0           0
# ..        ...          ...         ...
# 728         0            0           1
# 729         0            0           1
# 730         0            0           1
# 731         0            0           1
# 732         0            0           1
#
# [733 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.set()

# %%
sns.countplot(dataset['zones'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zones'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-f20d5a33a937> in <module>
# ----> 1 sns.countplot(dataset['zones'])
#
# ...
